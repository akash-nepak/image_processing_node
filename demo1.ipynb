# %%
import  pandas as pd
import torch.nn as nn
import  torch.nn.functional as F
import torchvision

# %%
x = 322

# %%
print(x)
# Out:
# 322

# %%
# !pip install vscode-colab --upgrade
# Out:
# Collecting vscode-colab
#   Downloading vscode_colab-0.3.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from vscode-colab) (2.32.4)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from vscode-colab) (7.34.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from vscode-colab) (3.1.6)
# Collecting loguru (from vscode-colab)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->vscode-colab) (75.2.0)
# Collecting jedi>=0.16 (from ipython->vscode-colab)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->vscode-colab) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->vscode-colab) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->vscode-colab) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->vscode-colab) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->vscode-colab) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->vscode-colab) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->vscode-colab) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->vscode-colab) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->vscode-colab) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->vscode-colab) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->vscode-colab) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->vscode-colab) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->vscode-colab) (2025.10.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->vscode-colab) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->vscode-colab) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->vscode-colab) (0.2.14)
# Downloading vscode_colab-0.3.1-py3-none-any.whl (33 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 2.7 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.7 MB/s eta 0:00:00
# Installing collected packages: loguru, jedi, vscode-colab
# Successfully installed jedi-0.19.2 loguru-0.7.3 vscode-colab-0.3.1

# %%
from vscode_colab import login ,connect

# %%
login()
# Out:
# 2025-11-08 08:27:19 | INFO     | vscode_colab.server:download_vscode_cli:74 - Downloading VS Code CLI (cli-alpine-x64) to /content/vscode_cli_alpine_x64.tar.gz...
# 2025-11-08 08:27:20 | INFO     | vscode_colab.server:download_vscode_cli:87 - VS Code CLI tarball downloaded. Extracting...
# 2025-11-08 08:27:20 | INFO     | vscode_colab.server:download_vscode_cli:171 - VS Code CLI setup successful. Executable at: '/content/code'.
# 2025-11-08 08:27:20 | INFO     | vscode_colab.server:_login:220 - Initiating VS Code Tunnel login with command: /content/code tunnel user login --provider github
# 2025-11-08 08:27:20 | INFO     | vscode_colab.server:_login:254 - Monitoring login process output for GitHub authentication URL and code...
# 2025-11-08 08:27:20 | INFO     | vscode_colab.server:_login:272 - Detected authentication URL: https://github.com/login/device
# 2025-11-08 08:27:20 | INFO     | vscode_colab.server:_login:278 - Detected authentication code: 2DF3-4DDE
# 2025-11-08 08:27:20 | INFO     | vscode_colab.server:_login:281 - Authentication URL and code detected. Displaying to user.
# <div style="padding: 15px; background-color: #f0f7ff; border-radius: 8px; margin: 15px 0; font-family: Arial, sans-serif; border: 1px solid #c8e1ff; line-height: 1.6;">
#     <h3 style="margin-top: 0; color: #0366d6; font-size: 18px;">GitHub Authentication Required</h3>
#     <p style="margin-bottom: 15px; color: #333333;">Please open the link below in a new tab and enter the following code:</p>
#     <div style="display: flex; align-items: center; margin-bottom: 15px; flex-wrap: wrap; gap: 15px;">
#         <a href="https://github.com/login/device" target="_blank"
#             style="background-color: #2ea44f; color: white; padding: 10px 16px; text-decoration: none; border-radius: 6px; font-weight: 500; white-space: nowrap;">
#             Open GitHub Authentication Page
#         </a>
#         <div id="code-container" style="background-color: #ffffff; border: 1px solid #d1d5da; border-radius: 6px; padding: 10px 16px; font-family: 'SFMono-Regular', Consolas, 'Liberation Mono', Menlo, monospace; display: flex; align-items: center;">
#             <span id="auth-code" style="margin-right: 15px; font-size: 16px; user-select: all; color: #24292e;">2DF3-4DDE</span>
#         </div>
#     </div>
#     <p id="copy-fallback-note" style="font-size: small; color: #586069; margin-top: 10px; display: none;">
#         Please select the code manually and copy it.
#     </p>
#     <script>
#         (function() {
#             // The Jinja2 'tojson' filter correctly escapes the string for JavaScript.
#             const codeToCopy = "2DF3-4DDE";
#             const codeContainer = document.getElementById('code-container');
#             const fallbackNote = document.getElementById('copy-fallback-note');
#
#             function attemptCopy() {
#                 const copyButton = document.getElementById('dynamicCopyButton');
#                 if (!copyButton) return;
#
#                 navigator.clipboard.writeText(codeToCopy).then(() => {
#                     copyButton.textContent = 'Copied!';
#                     copyButton.style.backgroundColor = '#dff0d8';
#                     copyButton.style.borderColor = '#d6e9c6';
#                     copyButton.style.color = '#3c763d';
#                     setTimeout(() => {
#                         copyButton.textContent = 'Copy';
#                         copyButton.style.backgroundColor = '#f6f8fa';
#                         copyButton.style.borderColor = '#d1d5da';
#                         copyButton.style.color = '';
#                     }, 2500);
#                 }).catch(err => {
#                     console.error('Failed to copy code automatically: ', err);
#                     copyButton.textContent = 'Copy Failed';
#                     copyButton.disabled = true;
#                     copyButton.style.backgroundColor = '#f2dede';
#                     copyButton.style.borderColor = '#ebccd1';
#                     copyButton.style.color = '#a94442';
#                     fallbackNote.style.display = 'block';
#                 });
#             }
#
#             if (navigator.clipboard && navigator.clipboard.writeText) {
#                 const button = document.createElement('button');
#                 button.id = 'dynamicCopyButton';
#                 button.textContent = 'Copy';
#                 button.style.backgroundColor = '#f6f8fa';
#                 button.style.border = '1px solid #d1d5da';
#                 button.style.borderRadius = '6px';
#                 button.style.padding = '6px 12px';
#                 button.style.cursor = 'pointer';
#                 button.style.fontSize = '14px';
#                 button.style.whiteSpace = 'nowrap';
#                 button.style.marginLeft = '10px';
#                 button.onclick = attemptCopy;
#                 codeContainer.appendChild(button);
#             } else {
#                 fallbackNote.style.display = 'block';
#             }
#         })();
#     </script>
# </div>
# 2025-11-08 08:27:20 | INFO     | vscode_colab.server:login:200 - Login successful: Set environment variable VSCODE_COLAB_LOGGED_IN=true
# True

# %%
connect()
# Out:
# 2025-11-08 08:43:15 | INFO     | vscode_colab.server:connect:579 - Initial CWD for connect operation: /content
# 2025-11-08 08:43:15 | INFO     | vscode_colab.server:download_vscode_cli:58 - VS Code CLI already exists and is executable at /content/code. Skipping download.
# 2025-11-08 08:43:15 | INFO     | vscode_colab.server:_launch_and_monitor_tunnel:457 - Starting VS Code tunnel with command: /content/code tunnel --accept-server-license-terms --name colab --install-extension mgesbert.python-path --install-extension ms-python.black-formatter --install-extension ms-python.debugpy --install-extension ms-python.isort --install-extension ms-python.python --install-extension ms-python.vscode-pylance --install-extension ms-toolsai.jupyter --install-extension ms-toolsai.jupyter-keymap --install-extension ms-toolsai.jupyter-renderers --install-extension ms-toolsai.tensorboard
# 2025-11-08 08:43:15 | INFO     | vscode_colab.server:_launch_and_monitor_tunnel:458 - Tunnel will run with CWD: /content
# 2025-11-08 08:43:15 | INFO     | vscode_colab.server:_launch_and_monitor_tunnel:483 - Monitoring tunnel 'colab' process output for connection URL...
# 2025-11-08 08:43:15 | INFO     | vscode_colab.server:_launch_and_monitor_tunnel:505 - VS Code Tunnel URL for 'colab' detected: https://vscode.dev/tunnel/colab/content
# <div style="padding:15px; background:#f0f9f0; border-radius:8px; margin:15px 0; font-family:Arial,sans-serif; border:1px solid #c8e6c9; line-height: 1.6;">
#     <h3 style="margin:0 0 15px; color:#2e7d32; font-size: 18px;">✅ VS Code Tunnel Ready!</h3>
#     <p style="margin-bottom: 15px; color: #333333;">You can connect in two ways:</p>
#     <div style="margin-bottom: 15px;">
#         <strong style="color: #333333;">1. Open in Browser:</strong><br>
#         <a href="https://vscode.dev/tunnel/colab/content" target="_blank"
#             style="background-color:#1976d2; color:white; padding:10px 16px; border-radius:6px; text-decoration:none; font-weight:500; display:inline-block; margin-top: 5px;">
#             Open VS Code Web
#         </a>
#     </div>
#     <hr style="border: 0; border-top: 1px solid #c8e6c9; margin: 20px 0;" />
#     <div style="margin-bottom: 10px; color: #333333;">
#         <strong style="color: #333333;">2. Connect from Desktop VS Code:</strong>
#         <ol style="margin-top: 5px; padding-left: 20px; color: #333333;">
#             <li>Make sure you have the <a href="https://marketplace.visualstudio.com/items?itemName=ms-vscode.remote-server" target="_blank" style="color: #1976d2;">Remote Tunnels</a> extension installed.</li>
#             <li>Ensure you are signed in to VS Code with the <strong>same GitHub account</strong> used for authentication.</li>
#             <li>Open the Command Palette (<kbd style="background: #e0e0e0; color: #333; padding: 2px 4px; border-radius: 3px; border: 1px solid #ccc; font-family: monospace;">Ctrl+Shift+P</kbd> or <kbd style="background: #e0e0e0; color: #333; padding: 2px 4px; border-radius: 3px; border: 1px solid #ccc; font-family: monospace;">Cmd+Shift+P</kbd>).</li>
#             <li>Run the command: <code style="background: #e0e0e0; color: #333; padding: 2px 5px; border-radius: 3px;">Remote Tunnels: Connect to Tunnel</code></li>
#             <li>Select the tunnel named "<strong style="color: #333333;">colab</strong>" from the list.</li>
#         </ol>
#     </div>
# </div>
# 2025-11-08 08:43:15 | INFO     | vscode_colab.server:connect:627 - VS Code tunnel 'colab' process started successfully.
# <Popen: returncode: None args: ['/content/code', 'tunnel', '--accept-server-...>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
